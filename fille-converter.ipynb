# %%
import pandas as pd


data = pd.read_spss("C:/Users/jerem/OneDrive/Desktop/Jali/HIV adherence dataset for Figshare AIDs CARE (1).sav")

data.to_csv("HIV adherence dataset for Figshare AIDs CARE (1).csv", index=False)

# %%
import pandas as pd

data = pd.read_excel("C:\\Users\\jerem\\OneDrive\\Desktop\\Jali\\QualityOfCare.xlsx")

data.to_csv("C:/Users/jerem/OneDrive/Desktop/Jali/QualityOfCare.csv", index=False)
